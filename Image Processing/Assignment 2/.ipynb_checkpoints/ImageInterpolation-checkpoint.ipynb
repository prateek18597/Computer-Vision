# %% [markdown]
# <h2>Pratik Parmar</h2>
# <h3>2016UCS0049</h3>

# %% [markdown]
# **Importing Libraries**

# %%
import cv2
import numpy as np
from numpy.linalg import inv
import math
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from skimage.measure import structural_similarity as ssim

# %% [markdown]
# **Taking Images as Input**

# %%
img=cv2.imread("./OriginalImages/1.tif")
img1=cv2.imread("./OriginalImages/2.tif")
img2=cv2.imread("./OriginalImages/3.tif")
img3=cv2.imread("./OriginalImages/4.tif")
images=[img,img1,img2,img3]

# %% [markdown]
# **Defining Bilateral Filter**<br>
# A *bilateral filter* is a non-linear, edge-preserving, and noise-reducing smoothing filter for images. It replaces the intensity of each pixel with a weighted average of intensity values from nearby pixels. This weight can be based on a Gaussian distribution.<br>

# %%
def bilateral_filter(X_matrix,size,sigma_d,sigma_r):
	X=np.zeros((len(X_matrix),len(X_matrix[0])))
	center=size//2    
	for j in range(center,len(X_matrix)-center,1):
		for k in range(center,len(X_matrix[0])-center,1):
			temp=0;
			w_sum=0;
			for m in range(-center,center+1,1):
				for n in range(-center,center+1,1):
					w=math.exp(-(((m)**2+(n)**2)/(2*sigma_d*sigma_d))-((abs(X_matrix[j+m][k+n]-X_matrix[j][k]))/(2*sigma_r*sigma_r)))
					temp+=X_matrix[j+m][k+n]*w;
					w_sum+=w;
			X[j][k]=temp//(w_sum);
	return X;

# %% [markdown]
# **Defining Interpolation function, Bilinear Interpolation Algorithm has been used for this.**<br>
# *Bilinear Interpolation*<br>
# In Bilinear Interpolation, a pixel is predicted by using neighbouring 4 pixels. New pixel is average of those 4 pixels. For First and last columns and rows, new pixels is generated by using average of surrounding 2 pixels.<br>
# Bilateral Filter has been applied on interpolated image to reducing any effect of aliasing.

# %%
def interpolate(img):
    x,y,z=img.shape;
    x*=2
    y*=2
    image=np.zeros((x,y,3));
    for k in range(0,3,1):
        for i in range(0,x,2):
            for j in range(0,y,2):
                image[i,j,k]=img[i//2,j//2,k];
        
    for k in range(0,3,1):
        for i in range(1,x-1,2):
            for j in range(1,y-1,2):
                image[i,j,k]=(image[i-1,j-1,k]+image[i+1,j-1,k]+image[i-1,j+1,k]+image[i+1,j+1,k])//4;
                
    for k in range(0,3,1):
        for i in range(1,x-2,2):
            for j in range(2,y-2,2):
                image[i,j,k]=(image[i-1,j,k]+image[i+1,j,k]+image[i,j+1,k]+image[i,j-1,k])//4;

    for k in range(0,3,1):
        for i in range(2,x-2,2):
            for j in range(1,y-2,2):
                image[i,j,k]=(image[i-1,j,k]+image[i+1,j,k]+image[i,j+1,k]+image[i,j-1,k])//4;

    for k in range(0,3,1):
        for j in range(1,y-1,2):
            image[0,j,k]=(image[0,j-1,k]+image[i,j+1,k])//2
    for k in range(0,3,1):
        for j in range(1,y-1,2):
            image[x-1,j,k]=(image[x-2,j-1,k]+image[x-2,j+1,k])//2
    for k in range(0,3,1):
        for j in range(1,x-1,2):
            image[j,0,k]=(image[j-1,0,k]+image[j+1,0,k])//2
    for k in range(0,3,1):
        for j in range(1,x-1,2):
            image[j,y-2,k]=(image[j-1,y-2,k]+image[j+1,y-2,k])//2
    for k in range(0,3,1):
        image[x-1,y-1,k]=image[x-2,y-2,k];
        
    for k in range(0,3,1):
        for j in range(0,y-1,1):
            image[x-1,j,k]=(image[x-2,j,k])
    for k in range(0,3,1):
        for j in range(0,x,1):
            image[j,y-1,k]=(image[j,y-2,k])

    image[:,:,0]=bilateral_filter(image[:,:,0],3,2,0.25)
    image[:,:,1]=bilateral_filter(image[:,:,1],3,2,0.25)
    image[:,:,2]=bilateral_filter(image[:,:,2],3,2,0.25)
    
    return image;

# %% [markdown]
# **Interpolating Images**

# %%
interpolated_images=[];
for i in images:
    interpolated_images.append(interpolate(i))

# %% [markdown]
# **Storing Interpolated Images and Displaying them.**

# %%
cv2.imwrite("Image1.tif",interpolated_images[0]);
cv2.imwrite("Image2.tif",interpolated_images[1]);
cv2.imwrite("Image3.tif",interpolated_images[2]);
cv2.imwrite("Image4.tif",interpolated_images[3]);

Image1=cv2.imread("Image1.tif")
Image2=cv2.imread("Image2.tif")
Image3=cv2.imread("Image3.tif")
Image4=cv2.imread("Image4.tif")

f, ax = plt.subplots(2,2,figsize=(18,18))
ax[0,0].imshow(Image1)
ax[0,0].set_title("Image 1")
ax[0,1].imshow(Image2)
ax[0,1].set_title("Image 2")
ax[1,0].imshow(Image3)
ax[1,0].set_title("Image 3")
ax[1,1].imshow(Image4)
ax[1,1].set_title("Image 4")
# Out:
# Text(0.5,1,u'Image 4')

# %% [markdown]
# **Showing Original image.**

# %%
f, ax = plt.subplots(2,2,figsize=(15,15))
ax[0,0].imshow(images[0])
ax[0,0].set_title("Image 1")
ax[0,1].imshow(images[1])
ax[0,1].set_title("Image 2")
ax[1,0].imshow(images[2])
ax[1,0].set_title("Image 3")
ax[1,1].imshow(images[3])
ax[1,1].set_title("Image 4")
# Out:
# Text(0.5,1,u'Image 4')

# %% [markdown]
# **Analysis**<hr>
# *Brisque Values for Original Images*
# <ul>
#     <li>1.tif:  12.477854470630604
#     <li>2.tif:  4.129269013906281
#     <li>3.tif:  -3.356869612333668
#     <li>4.tif:  14.267063900673605
# </ul>
# *Brisque Values for Interpolated Images*
# <ul>
#     <li>Image1.tif:  52.42499514744415
#     <li>Image2.tif:  39.46962241180083
#     <li>Image3.tif:  45.06097927413131
#     <li>Image4.tif:  59.36577578255773
# </ul>
# *It can be easily observed that interpolation reduces quality of image.*<br>
# *Upon carefully observing images, It has been observed that edges has been blurred a bit in interpolated image.*
